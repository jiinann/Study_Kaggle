# %% [markdown]
# ## Intro
# + Basic attempt at topic modelling
# + Topic modelling: process to uncover abstract themes/topics based on the underlying documents and words in texts
# + Two standard topic modelling methods to be introduced:
#     1. Latent Dirichlet Allocation (LDA)
#     2. Non-negative Matrix Factorization (NMF)
#     3. Additionally, some Natural Language basics such as Tokenization, Stemming & vectorization of the raw text
#
# ### Outline
# 1. Expoloratory Data Analysis (EDA) & Wordclouds; Data analysis by simple stats generation (i.e. word frequencies over different authors, plotting wordsclouds w. image masks)
# 2. Natural Language Processing (NLP) w. NLTK (Natural Language Toolkit); Intro of basic text processing methods (i.e. tokenizations, stop word removal, stemming & vectorizing text via term frequencies (TF), inverse document frequencies (TF-IDF)
# 3. Topic Modelling with LDA and NNMF; Implementation of two topic modelling techniques of LDA & NMF

# %%
import base64 # 이진데이터를 ASCII 문자로 인코딩 (반대의 경우, 디코딩) 하는 함수 제공
import numpy as np
import pandas as pd

# Plotly imports
import plotly.offline as py # 오프라인으로 그래프 생성 및 로컬 저장 가능 (plotly.offline.plot() & plotly.offline.iplot())
py.init_notebook_mode(connected = True) # plotly.offline.iplot 사용을 위해 실행하는 초기화 단계
import plotly.graph_objs as go
import plotly.tools as tls

# Others
from collections import Counter # collections; 데이터 처리를 위한 객체 제공
from imageio import imread # 이미지 불러오기 / scipy 1.2.0 이후 버전 "from scipy.misc import imread" 코드 에러 발생 --> from imageio로 변경/실행
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
    # 문서 전처리용 클래스 제공;
    # TfidfVectorizer - TF-IDF 방식, 단어의 가중치를 조정한 BOW 인코딩 벡터 생성
    # CountVectorizer - 문서 집합의 단어 토큰 생성 및 각 단어 수 세어 BOW 인코딩 벡터 생성
from sklearn.decomposition import NMF, LatentDirichletAllocation
    # 토픽 모델링 = 문서의 집합에서 토픽을 찾아내는 프로세스 (검색엔진, 고객민원 등 문서 주제 파악이 중요한 곳에서 사용)
    # NMF
    # LatentDirichletAllocation - 잠재 디리클레 할당; 
        # 토픽 모델링의 대표적 알고리즘
        # 토픽들의 혼합으로 구성된 LDA 문서, 토픽들은 확률 분포에 기반하여 단어 생성한다고 가정
        # 데이터가 주어지면, LDA는 문서가 생성되던 과정을 역추적
        
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
train = pd.read_csv('C:/Python/00 Study/007_Spooky Author Identification_Spooky NLP and Topic Modelling tutorial/train.csv')

# %% [markdown]
# ## 1. The Authors and Their Works EDA

# %%
train.head()
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %% [markdown]
# + 3 distinct author initials provided with a map
#
# 1. EAP - Edgar Allen Poe:
#     - American writer
#     - Poetry, short stories > major themes such as mystery, the grisly & the grim
#     - The most famous work, poem - 'The Raven'
#     - A pioneer of detective fiction genre
#
# 2. HPL - HP Lovecraft:
#     - Best known for horror fictions
#     - Most celebrated for fictional mythology and for the infamous creature 'Cthulhu' - a hybrid chimera mix of Octopus head and numanoid body w. wings on the back
#
# 3. MWS = Mary Shelley:
#     - Novelist, dramatist, travel-writer, biographer
#     - Most celebrated for the classic tale of Frankenstein

# %%
print(train.shape)
# Out:
# (19579, 3)

# %% [markdown]
# ### Summary Stats of the Training Set

# %%
z = {'EAP': 'Edgar Allen Poe', 'MWS': 'Mary Shelley', 'HPL': 'HP Lovecraft'}

data = [go.Bar(x = train.author.map(z).unique(), # go.Bar - 막대 그래프 형식 출력 / map - 리스트의 요소에 특정 함수 적용 시 사용
               y = train.author.value_counts().values,
               marker = (dict(colorscale = 'Jet',
                             color = train.author.value_counts().values)),
               text = 'Text entries attributed to Author'
              )
       ]

layout = go.Layout(
    title = 'Target variable distribution')

fig = go.Figure(data = data, layout = layout)

py.iplot(fig, filename = 'basic-bar') # filename - 추후 png 파일로 그래프 저장 시 파일명 지정
# Out:
# <div>                            <div id="b281a4ec-4e24-411b-9a5e-44f8adcefbf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b281a4ec-4e24-411b-9a5e-44f8adcefbf3")) {                    Plotly.newPlot(                        "b281a4ec-4e24-411b-9a5e-44f8adcefbf3",                        [{"marker":{"color":[7900,6044,5635],"colorscale":[[0.0,"rgb(0,0,131)"],[0.2,"rgb(0,60,170)"],[0.4,"rgb(5,255,255)"],[0.6,"rgb(255,255,0)"],[0.8,"rgb(250,0,0)"],[1.0,"rgb(128,0,0)"]]},"text":"Text entries attributed to Author","x":["Edgar Allen Poe","HP Lovecraft","Mary Shelley"],"y":[7900,6044,5635],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"s
# ...

# %%
all_words = train['text'].str.split(expand = True).unstack().value_counts() 
    # expand = True - 여러 컬럼에 리스트 / False - 1개 컬럼에 리스트
    # unstack() - 인덱스 값을 컬럼으로 올림
data = [go.Bar(x = all_words.index.values[2:50], # 왜 0이 아닌 2부터 시작?
               y = all_words.values[2:50],
               marker = dict(colorscale = 'Jet',
                             color = all_words.values[2:100]), # 막대 색상 설정
               text = 'Word counts')
       ]

layout = go.Layout(
    title = 'Top 50 (uncleaned) Word Frequencies in the Training Dataset')

fig = go.Figure(data = data, layout = layout)

py.iplot(fig, filename = 'basic-bar')
# Out:
# <div>                            <div id="573f539f-e725-442e-99ec-86d196582a9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("573f539f-e725-442e-99ec-86d196582a9e")) {                    Plotly.newPlot(                        "573f539f-e725-442e-99ec-86d196582a9e",                        [{"marker":{"color":[17059,12615,10382,10359,8787,6440,5988,5037,4324,4207,3802,3528,3422,3247,3227,3203,3048,2925,2758,2725,2533,2521,2285,2268,2121,2118,2089,2015,2007,1953,1691,1679,1644,1500,1428,1395,1373,1372,1347,1308,1259,1215,1202,1178,1134,1104,1100,1036,992,957,954,929,925,924,915,901,880,873,863,861,829,823,814,751,713,707,701,648,645,645,638,624,623,600,595,592,576,575,574,565,550,545,539,534,532,531,527,527,526,503,502,497,493,493,491,488,486,482],"c
# ...

# %%
all_words
# Out:
# the          33296
# of           20851
# and          17059
# to           12615
# I            10382
#              ...
# sunrise."        1
# Averni;          1
# buildin's        1
# useless;         1
# reduced?         1
# Length: 47556, dtype: int64

# %% [markdown]
# + Oddly, words w. high appearance frequency do not imply the themes/concepts that MWS wishes to portray
# + Commonly occuring words in any type of english literature
#     --> Preprocessing step to strip these words is required

# %% [markdown]
# ### WordClouds to Visualize Each Author's Work

# %% [markdown]
# **Store the text of each author in a Python list**
# - 3 different Python lists created to stroe the texts of EAP, HPL & MWS respectively

# %%
eap = train[train.author == 'EAP']['text'].values
hpl = train[train.author == 'HPL']['text'].values
mws = train[train.author == 'MWS']['text'].values

# %%
eap # 위 정의된 변수 1가지 확인, EAP의 text 값 array
# Out:
# array(['This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.',
#        'In his left hand was a gold snuff box, from which, as he capered down the hill, cutting all manner of fantastic steps, he took snuff incessantly with an air of the greatest possible self satisfaction.',
#        'The astronomer, perhaps, at this point, took refuge in the suggestion of non luminosity; and here analogy was suddenly let fall.',
#        ..., 'The lids clenched themselves together as if in a spasm.',
#        'Mais il faut agir that is to say, a Frenchman never faints outright.',
#        'For an item of news like this, it strikes us it was very coolly received."'],
#       dtype=object)

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# 1. The Raven, Edger Allen Poe
# 2. Octopus Cthulu-thingy, HP Lovecraft
# 3. Frankenstein, Mary Shelly

# %%
eap_64 = b'...'

# %%
hpl_64 = b'...'

# %%
mws_64 = b'...'

# %%
import codecs # 임의의 코덱으로 인코딩과 디코딩하는 함수 정의

# Generate the mask for EAP
f1 = open('eap.png', 'wb') # wb - 바이너리 쓰기 모드
f1.write(codecs.decode(eap_64, 'base64'))
f1.close()
img1 = imread('eap.png')
# img = img.resize((980, 1080))
hcmask = img1

# for HPL
f2 = open('hpl.png', 'wb')
f2.write(codecs.decode(hpl_64, 'base64'))
f2.close()
img2 = imread('hpl.png')
hcmask2 = img2

# for MWS
f3 = open('mws.png', 'wb')
f3.write(codecs.decode(mws_64, 'base64'))
f3.close()
img3 = imread('mws.png')
hcmask3 = img3

# %%
# The wordcloud of the Raven for EAP
plt.figure(figsize = (20, 18))
plt.subplot(211)
wc = WordCloud(background_color = 'black',
               max_words = 10000,
               mask = hcmask,
               stopwords = STOPWORDS,
               max_font_size = 40)
wc.generate(' '.join(eap))
plt.title('Edgar Allen Poe (The Raven)')
plt.imshow(wc.recolor(colormap = 'PuBu',
                      random_state = 17), alpha = 0.9)
plt.axis('off')
# Out:
# (-0.5, 639.5, 390.5, -0.5)

# %%
# The wordcloud of Cthulhu/squidy thing for HP Lovecraft
plt.figure(figsize = (16, 13))
wc = WordCloud(background_color = 'black',
               max_words = 10000,
               mask = hcmask2,
               stopwords = STOPWORDS,
               max_font_size = 40)
wc.generate(' '.join(hpl))
plt.title('HP Lovecraft (Cthulhu-Squidy)', fontsize = 20)
# plt.imshow(wc.recolor(colormap = 'Pastel1_r', random_state = 17), alpha = 0.98)
plt.imshow(wc.recolor(colormap = 'Pastel2',
                      random_state = 17), alpha = 0.98)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# The wordcloud of Frankenstein for Mary Shelley
plt.figure(figsize = (20, 18))
wc = WordCloud(background_color = 'black',
               max_words = 10000,
               mask = hcmask3,
               stopwords = STOPWORDS,
               max_font_size = 40)
wc.generate(' '.join(mws))
plt.title('Mary Shellley (Frankenstein\'s Monster)', fontsize = 18)
plt.imshow(wc.recolor(colormap = 'viridis',
                      random_state = 17), alpha = 0.9)
plt.axis('off')
# Out:
# (-0.5, 639.5, 589.5, -0.5)

# %% [markdown]
# Each author's word choice observed

# %% [markdown]
# ## 2. Natural Language Processing

# %% [markdown]
# + Natural language processing involves pre-processing steps to convert the input raw text into a readable form by created models and the machine
# + Simple breakdoown of text pre-processing steps
#     1. Tokenization - segregation of the test into its individual constituent words
#     2. Stopwords - Unnecessary (determined by its frequency, etc.) words to be eliminated for better detection of relevant texts
#     3. Stemming - Combinining variants of words into a single parent word that still conveys the same meaning
#     4. Vectorization - Converting texts into vector format. The simplest approach = bag-of-words where a matrix (for each doc or text in the corpus) is created. The matrix stores word frequencies (word counts) and is referred to as vectorization of the raw text
#
# + Natural language toolkit (NLTK)

# %%
import nltk

# %% [markdown]
# ### 2a. Tokenization
# The act of taking a sequence of characters in a given doc and dicing it up into its individual constituent pieces<br><br>
#
# Below example shows a sentence in training data splitted simply by space:

# %%
# Storing the first text element as a string
first_text = train.text.values[0]

print(first_text)
print('=' * 90)
print(first_text.split(' '))
# Out:
# This process, however, afforded me no means of ascertaining the dimensions of my dungeon; as I might make its circuit, and return to the point whence I set out, without being aware of the fact; so perfectly uniform seemed the wall.
# ...
# ['This', 'process,', 'however,', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon;', 'as', 'I', 'might', 'make', 'its', 'circuit,', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out,', 'without', 'being', 'aware', 'of', 'the', 'fact;', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall.']

# %% [markdown]
# Above displays elements separated are not entirely accurate (word + , and such)<br>
# --> NLTK library helps organize these elements more accurately (word_tokenize() strips out singular words as well as punctuations into separate elemetns automatically)<br>
# Following example demonstrates the explained:

# %%
first_text_list = nltk.word_tokenize(first_text) # first_text 문단을 단어 및 punctuation 단위로 쪼개어 리스트 생성

print(first_text_list)
# Out:
# ['This', 'process', ',', 'however', ',', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'of', 'my', 'dungeon', ';', 'as', 'I', 'might', 'make', 'its', 'circuit', ',', 'and', 'return', 'to', 'the', 'point', 'whence', 'I', 'set', 'out', ',', 'without', 'being', 'aware', 'of', 'the', 'fact', ';', 'so', 'perfectly', 'uniform', 'seemed', 'the', 'wall', '.']

# %% [markdown]
# ### 2b. Stopword Removal
# + Too frequently appearing words/definite words/etc. to be removed
# + NLTK provides a predefined list of 153 english stopwords

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords) # 179개의 영어 단어로 구성된 english stopwords
# Out:
# 179

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %% [markdown]
# To filter out stopwords from the tokenized list of words, following list comprehension is used:

# %%
first_text_list_cleaned = [word for word in first_text_list if word.lower() not in stopwords]
    # stopwords를 제외한 단어 리스트 형성

print(first_text_list_cleaned) 
print('=' * 90)
print('Length of original list: {0} words\n'
      'Length of list after stopwords removal: {1} words'
      .format(len(first_text_list), len(first_text_list_cleaned)))
# Out:
# ['process', ',', 'however', ',', 'afforded', 'means', 'ascertaining', 'dimensions', 'dungeon', ';', 'might', 'make', 'circuit', ',', 'return', 'point', 'whence', 'set', ',', 'without', 'aware', 'fact', ';', 'perfectly', 'uniform', 'seemed', 'wall', '.']
# ...
# Length of original list: 48 words
# Length of list after stopwords removal: 28 words

# %% [markdown]
# ### 2c. Stemming and Lemmatization
# + To reduce as many different variations of similar words into a single term (diff branches all reduced to single word stem)
# + eg. 'running' 'runs' 'run' to collapse into the word 'run'
# + NLTK also provides various stemmers including the Porter stemming algorithm, the lancaster stemmer and the Snowball stemmer<br><br>
#
# A porter stemmer instance shown as follows:

# %%
stemmer = nltk.stem.PorterStemmer() # 동사 등을 모두 원형으로 출력하는 stemmer 정의

# %%
print('The stemmed form of running is: {}'.format(stemmer.stem('running')))
print('The stemmed form of runs is: {}'.format(stemmer.stem('runs')))
print('The stemmed form of run is: {}'.format(stemmer.stem('run')))
# Out:
# The stemmed form of running is: run
# The stemmed form of runs is: run
# The stemmed form of run is: run

# %% [markdown]
# + A flaw w. stemming - a crude heuristic in chopping off the ends of words --> the process often does not take vocabs/word forms into account as below shows:

# %%
print('The stemmed form of leaves is: {}'.format(stemmer.stem('leaves'))) # 단순히 es를 제거 후 nonsense 단어를 출력함
# Out:
# The stemmed form of leaves is: leav

# %% [markdown]
# #### Lemmatization to the rescue
# + Lemmatization is used in lieu of stemming
# + It aims to achieve the same as the former + the dataset aims to reduce words based on an actual dictionary or vocab (the Lemma) --> words won't be chopped off and print nonsense words<br><br>
#
# An example as follows:

# %%
from nltk.stem import WordNetLemmatizer # nltk.download('wordnet') / nltk.download('omw-1.4') 진행

lemm = WordNetLemmatizer() # stemmer를 보완할 lemm

print('The lemmatized form of leaves is: {}'.format(lemm.lemmatize('leaves')))
# Out:
# The lemmatized form of leaves is: leaf

# %% [markdown]
# ### 2d. Vectorizing Raw Text
# + Various purposes for text analysis
#     - Comparison between on body of text to antoher (clustering techs/distance measurements)
#     - Text classification
#     - Uncovering the topics of a text body
# + Conversion of human-readable to meachine-redable is required and will be established by the bag-of-words

# %% [markdown]
# **The Bag of Words Approach**
# + Using the counts of words as a starting block
# + Recording the occurence of each word (from the entire text) in a vector specific to the particular word
# + Each word now becomes an individual feature/column in the new transformed dataset
# + Scikit-learn used to implement a vectorizer that generates a vector of word counts via CountVectorizer
#
# An example as follows:

# %%
# Defining our sentence
sentence = ['I love to eat Burgers',
            'I love to eat Fries']
vectorizer = CountVectorizer(min_df = 0) 
    # max_df 단어 빈도수 최대 값 / min_df 단어 빈도수 최소 값 - 각 설정 값 외 범위의 단어는 제외
sentence_transform = vectorizer.fit_transform(sentence)

# %% [markdown]
# **Fitting the Vectorizer to the Dataset**
# + A simple term frequency object initialized & created via CountVectorizer function
# + Parameters explicitly provided = bare minimum and the rest left as default
#     - min_df: minimum doc frequency; vectorizer drops all words that occur less than the set value (either integer / fraction form)
#     - For other parameters, refert to [SKlearn website](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html)
# + The fit.tranform method applied, comprised of two steps
#     - Vectorizer is mapped to the dataset provided
#     - The actual vectorizing operation via the transform method

# %%
print('The features are:\n {}'.format(vectorizer.get_feature_names()))
print('\nThe vectorized array looks like:\n{}'.format(sentence_transform.toarray()))
    # 업데이트로 인해 추후 get_feature_names 가 아닌 get_feature_names_out로 사용 필요
# Out:
# The features are:
#  ['burgers', 'eat', 'fries', 'love', 'to']
#
# The vectorized array looks like:
# [[1 1 0 1 1]
#  [0 1 1 1 1]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.

# %%
sentence_transform
# Out:
# <2x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Sparse matrix vector outputs**
# + The output of the vectorized text confirms that the features consist of the words in the corpus of text that was fed into the vectorizer
# + *"sparse matrix of type class 'numpy.int64' with 8 stored elements in Compressed Sparse Row format"* means that the vectorizer returns the transformed raw text as a matrix where most of its values are zero or almost negligible, hence the term sparse

# %% [markdown]
# ## 3. Topic Modelling
# Two different topic modelling techniques to be implemented as follows:<br>
#     1. **Latent Dirichlet Allocation** - Probabilistic, generative model which uncovers the topics latent to a dataset by assigning weights to words in a corpus, where each topic will assign different probability weights to each word.<br>
#     2. **Non-negative Matrix Factorization** - Approximation method that takes an input matrix and approximates the factorization of this matrix into two other matrices, w. the caveat that the values in the matrix be non-negative

# %%
# Define helper function to print top words
def print_top_words(model, feature_names, n_top_words):
    for index, topic in enumerate(model.components_):
        message = '\nTopic #{}:'.format(index)
        message += ' '.join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1 :-1]])
        print(message)
        print('=' * 70)

# %% [markdown]
# ### 3a. Putting all the preprocessing steps together
# + Sklearn vectorizers to be mentioned
#     - CountVectorizer - Dual stages of tokenizing and stopwords filtering automatically included as a high-level component
#     - Unlike the NLTK tokenizer introduced earlier (2a), it discards all single character terms ('a', 'w', etc.) + lower cases all terms by default
#     - Filtering stopwords in SKelarn as convenient as passing the 'english' value into the argument 'stop_words'
#     - No built-in lemmatizer, and the options are;
#         * Implementing separately everytime before feeding the data for vectorizing
#         * Extending the sklearn implementation to include the functionality (--> the option is given; extening CountVectorizer class by overwriting the 'build_analyzer' method as follows:

# %% [markdown]
# **Extending the CountVectorizer Class with a Lemmatizer**

# %%
lemm = WordNetLemmatizer()
class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(LemmaCountVectorizer, self).build_analyzer()
        return lambda doc: (lemm.lemmatize(w) for w in analyzer(doc))

# %% [markdown]
# - Subtle concepts used from Object_Oriented Programming (OOP)
# - The original Sklearn's CountVectorizer class inherited & subclassed
# - The build-analyzer method overwritten by implementing the lemmatizer for each list in the raw text matrix

# %%
# Storing the entrie training text in a list
text = list(train.text.values)

# Calling our overwritten Count vectorizer
tf_vectorizer = LemmaCountVectorizer(max_df = 0.95,
                                     min_df = 2,
                                     stop_words = 'english',
                                     decode_error = 'ignore')
tf = tf_vectorizer.fit_transform(text)

# %% [markdown]
# **Revisiting our Term Frequencies**
# + The plots for the term frequencies of the top 50 words to be revisited
# + W. the removal of stopwords, the remaining words now seem more meaningful

# %%
feature_names = tf_vectorizer.get_feature_names()
count_vec = np.asarray(tf.sum(axis = 0)).ravel()
zipped = list(zip(feature_names, count_vec))
x, y = (list(x) for x in zip(*sorted(zipped, key = lambda x: x[1], reverse = True)))

# Now I want to extract out on the top 15 and bottom 15 words
Y = np.concatenate([y[0:15], y[-16:-1]])
X = np.concatenate([x[0:15], x[-16:-1]])

# Plotting the Plot.ly plot for the Top 50 word frequencies
data = [go.Bar(
            x = x[0:50],
            y = y[0:50],
            marker = dict(colorscale = 'Jet',
                          color = y[0:50]
                         ),
            text = 'Word counts')]

layout = go.Layout(
    title = 'Top 50 Word Frequencies after Preprocessing')

fig = go.Figure(data = data, layout = layout)

py.iplot(fig, filename = 'basic-bar')

# Plotting the Plot.ly plot for the Top 50 word frequencies
data = [go.Bar(
            x = x[-100:],
            y = y[-100:],
            marker = dict(colorscale = 'Portland',
                          color = y[-100:]
                         ),
            text = 'Word counts')]

layout = go.Layout(
    title = 'Bottom 100 Word Frequencies after Preprocessing')

fig = go.Figure(data = data, layout = layout)

py.iplot(fig, filename = 'basic-bar')
# Out:
# <div>                            <div id="ac416f4d-12fe-46a1-84c4-7dccd48b96b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac416f4d-12fe-46a1-84c4-7dccd48b96b6")) {                    Plotly.newPlot(                        "ac416f4d-12fe-46a1-84c4-7dccd48b96b6",                        [{"marker":{"color":[869,779,743,725,707,704,700,616,613,609,586,576,531,512,511,503,488,465,461,451,445,428,419,408,401,401,385,376,370,368,366,363,361,354,343,343,343,341,340,337,337,336,327,325,322,319,308,300,300,296],"colorscale":[[0.0,"rgb(0,0,131)"],[0.2,"rgb(0,60,170)"],[0.4,"rgb(5,255,255)"],[0.6,"rgb(255,255,0)"],[0.8,"rgb(250,0,0)"],[1.0,"rgb(128,0,0)"]]},"text":"Word counts","x":["time","man","day","thing","eye","said","did","old","like","life","night"
# ...

# %% [markdown]
# ### 3b. Latent Dirichlet Allocation
# + Different implements of LDA algorithm available; SKlearn's implementation to be used here. [Radim Rehurek's gensim](https://radimrehurek.com/gensim/) is also well-known
#
# **Corpus - Document - Word: Topic Generation**
# + LDA modelling process revolves around 3 things, and therefore the algorithm attempts to uncover K topics from the corpus via follwing way as illustrated:
#     1. The text corpus
#     2. Its collection of documents (D)
#     3. The words W in the documents <br>
#
# ![lda_model_graph.png](attachment:lda_model_graph.png)
#
# Model each topic,  κ  via a Dirichlet prior distribution given by  βk:<br><br>
#
# Model each document d by another Dirichlet distribution parameterized by  α:<br><br>
#
# Subsequently for document d, we generate a topic via a multinomial distribution which we then backtrack and use to generate the correspondings words related to that topic via another multinomial distribution:<br><br>
#
# The LDA algorithm first models documents via a mixture model of topics. From these topics, words are then assigned weights based on the probability distribution of these topics. It is this probabilistic assignment over words that allow a user of LDA to say how likely a particular word falls into a topic. Subsequently from the collection of words assigned to a particular topic, are we thus able to gain an insight as to what that topic may actually represent from a lexical point of view.
#
# From a standard LDA model, there are really a few key parameters that we have to keep in mind and consider programmatically tuning before we invoke the model:
#
#     1. n_components: The number of topics that you specify to the model
#     2. α  parameter: This is the dirichlet parameter that can be linked to the document topic prior
#     3. β  parameter: This is the dirichlet parameter linked to the topic word prior
#
# To invoke the algorithm, we simply create an LDA instance through the Sklearn's LatentDirichletAllocation function. The various parameters would ideally have been obtained through some sort of validation scheme. In this instance, the optimal value of n_components (or topic number) was found by conducting a KMeans + Latent Semantic Analysis Scheme (as shown in this paper here) whereby the number of Kmeans clusters and number of LSA dimensions were iterated through and the best silhouette mean score.

# %%
lda = LatentDirichletAllocation(n_components = 11,
                                max_iter = 5,
                                learning_method = 'online',
                                learning_offset = 50.,
                                random_state = 0)

# %%
lda.fit(tf)
# Out:
# LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                           max_iter=5, n_components=11, random_state=0)

# %% [markdown]
# **Topics Generated by LDA**
# + The helper function defined earlier as 'print_top_words' to be used to return the top 10 words attributed to each of the DLDA generated topics
# + It is handled through the parameter n_components to select the number of topics

# %%
n_top_words = 40
print('\nTopics in LDA model: ')
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
#
# Topic #0:mean night fact young return great human looking wonder countenance difficulty greater wife finally set possessed regard struck perceived act society law health key fearful mr exceedingly evidence carried home write lady various recall accident force poet neck conduct investigation
# ...
#
# Topic #1:death love raymond hope heart word child went time good man ground evil long misery replied filled passion bed till happiness memory heavy region year escape spirit grief visit doe story beauty die plague making influence thou letter appeared power
# ...
#
# Topic #2:left let hand said took say little length body air secret gave right having great arm thousand character minute foot true self gentleman pleasure box clock discovered point sought pain nearly case best mere course manner balloon fear head going
# ...
#
# ...

# %%
first_topic = lda.components_[0]
second_topic = lda.components_[1]
third_topic = lda.components_[2]
fourth_topic = lda.components_[3]

# %%
first_topic.shape
# Out:
# (13781,)

# %% [markdown]
# **Word Cloud Visulization of the Topics**

# %%
first_topic_words = [tf_feature_names[i] for i in first_topic.argsort()[:-50 - 1 :-1]]
second_topic_words = [tf_feature_names[i] for i in second_topic.argsort()[:-50 - 1 :-1]]
third_topic_words = [tf_feature_names[i] for i in third_topic.argsort()[:-50 - 1 :-1]]
fourth_topic_words = [tf_feature_names[i] for i in fourth_topic.argsort()[:-50 -1 :-1]]

# %% [markdown]
# **Word Cloud of First Topic**

# %%
# Generating the wordcloud w. the values under the category dataframe
firstcloud = WordCloud(stopwords = STOPWORDS,
                       background_color = 'black',
                       width = 2500,
                       height = 1800).generate(' '.join(first_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
# Generating the wordcloud w. the values under the category dataframe
cloud = WordCloud(stopwords = STOPWORDS,
                  background_color = 'black',
                  width = 2500,
                  height = 1800).generate(' '.join(second_topic_words))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
# Generating the wordcloud w. the values under the category dataframe
cloud = WordCloud(stopwords = STOPWORDS,
                  background_color = 'black',
                  width = 2500,
                  height = 1800).generate(' '.join(third_topic_words))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
# Generating the wordcloud w. the values under the category dataframe
cloud = WordCloud(stopwords = STOPWORDS,
                  background_color = 'black',
                  width = 2500,
                  height = 1800).generate(' '.join(fourth_topic_words))
plt.imshow(cloud)
plt.axis('off')
plt.show()
